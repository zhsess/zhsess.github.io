# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Requirement already satisfied: getorg in /Users/hao/.local/lib/python3.8/site-packages (0.3.1)
# Requirement already satisfied: pygithub in /Users/hao/.local/lib/python3.8/site-packages (from getorg) (1.54.1)
# Requirement already satisfied: geopy in /Users/hao/.local/lib/python3.8/site-packages (from getorg) (2.1.0)
# Requirement already satisfied: retrying in /Users/hao/.local/lib/python3.8/site-packages (from getorg) (1.3.3)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/hao/.local/lib/python3.8/site-packages (from geopy->getorg) (1.50)
# Requirement already satisfied: pyjwt<2.0 in /Users/hao/.local/lib/python3.8/site-packages (from pygithub->getorg) (1.7.1)
# Requirement already satisfied: requests>=2.14.0 in /Users/hao/.conda/envs/obspy/lib/python3.8/site-packages (from pygithub->getorg) (2.25.1)
# Requirement already satisfied: deprecated in /Users/hao/.local/lib/python3.8/site-packages (from pygithub->getorg) (1.2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/hao/.conda/envs/obspy/lib/python3.8/site-packages (from requests>=2.14.0->pygithub->getorg) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hao/.conda/envs/obspy/lib/python3.8/site-packages (from requests>=2.14.0->pygithub->getorg) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/hao/.conda/envs/obspy/lib/python3.8/site-packages (from requests>=2.14.0->pygithub->getorg) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in /Users/hao/.conda/envs/obspy/lib/python3.8/site-packages (from requests>=2.14.0->pygithub->getorg) (2.10)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/hao/.conda/envs/obspy/lib/python3.8/site-packages (from deprecated->pygithub->getorg) (1.12.1)
# Requirement already satisfied: six>=1.7.0 in /Users/hao/.conda/envs/obspy/lib/python3.8/site-packages (from retrying->getorg) (1.15.0)
# IPywidgets and ipyleaflet support enabled.

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim(user_agent="zhsess@gmail.com")
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# San Francisco, CA
#  San Francisco, San Francisco City and County, California, United States

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
